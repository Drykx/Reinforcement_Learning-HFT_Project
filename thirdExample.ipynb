# %%
# Adjust the import according to what you installed
import gymnasium as gym

# Attempt to create and reset an environment
env = gym.make('CartPole-v1')  # Ensure 'CartPole-v1' is available in the installed package
env.reset()
print("Environment is ready.")

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

import sys
sys.path.append("../")

from mbt_gym.agents.BaselineAgents import CarteaJaimungalMmAgent
from mbt_gym.agents.BaselineAgents import AvellanedaStoikovAgent
from mbt_gym.gym.helpers.generate_trajectory import generate_trajectory
from mbt_gym.gym.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from mbt_gym.gym.TradingEnvironment import TradingEnvironment
from mbt_gym.gym.wrappers import *
from mbt_gym.rewards.RewardFunctions import PnL, CjMmCriterion, RunningInventoryPenalty
from mbt_gym.stochastic_processes.midprice_models import BrownianMotionMidpriceModel
from mbt_gym.stochastic_processes.arrival_models import PoissonArrivalModel, HawkesArrivalModel
from mbt_gym.stochastic_processes.fill_probability_models import ExponentialFillFunction
from mbt_gym.gym.ModelDynamics import LimitOrderModelDynamics

from mbt_gym.gym.helpers.plotting import generate_trajectory, generate_results_table_and_hist, plot_trajectory, plot_stable_baselines_actions


import importlib
# Out:
# Environment is ready.

# %%
terminal_time = 1.0
arrival_rate = 10.0
n_steps = int(20 * terminal_time * arrival_rate)
phi = 0.5
alpha = 0.001

# %%
def get_Hk_OF(num_trajectories:int = 1):
    fill_exponent = 1
    sigma = 0.1
    initial_inventory = (0,1) # 0$ in cash and 1$ dollars in stock
    initial_price = 100
    step_size = 1/n_steps
    timestamps = np.linspace(0, terminal_time, n_steps + 1)
    midprice_model = BrownianMotionMidpriceModel(volatility=sigma, step_size=1/n_steps,
                                                 num_trajectories=num_trajectories)
    
    # I should maybe specify the baseline rate
    arrival_model = HawkesArrivalModel(step_size=1/n_steps, 
                                        num_trajectories=num_trajectories)
    fill_probability_model = ExponentialFillFunction(fill_exponent=fill_exponent, 
                                                     step_size=1/n_steps,
                                                     num_trajectories=num_trajectories)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories)
    reward_function = RunningInventoryPenalty(per_step_inventory_aversion = phi, terminal_inventory_aversion = alpha)

    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      max_inventory=n_steps,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      reward_function = reward_function,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
env = ReduceStateSizeWrapper(get_Hk_OF(num_trajectories))
sb_env = StableBaselinesTradingEnvironment(trading_env=env)

# Monitor sb_env
sb_env = VecMonitor(sb_env)
# Add directory for tensorboard logging and best model
tensorboard_logdir = "./tensorboard/PPO-learning-CJ/"
best_model_path = "./SB_models/PPO-best-CJ"

policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])
PPO_params = {"policy":'MlpPolicy', "env": sb_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps)}
callback_params = dict(eval_env=sb_env, n_eval_episodes = 2048, #200 before  (n_eval_episodes)
                       best_model_save_path = best_model_path, 
                       deterministic=True)

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# d:\Anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.num_trajectories to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_trajectories` for environment variables or `env.get_wrapper_attr('num_trajectories')` that will search the reminding wrappers.
#   logger.warn(
# d:\Anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")
# d:\Anaconda3\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %%
model.learn(total_timesteps = 10_000_000)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to ./tensorboard/PPO-learning-CJ/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -39.7    |
# | time/              |          |
# |    fps             | 74136    |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 200000   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -48.1        |
# | time/                   |              |
# |    fps                  | 24656        |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 400000       |
# | train/                  |              |
# |    approx_kl            | 0.0016746046 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.00141     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.6         |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.000259    |
# |    std                  | 1            |
# |    value_loss           | 60.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -45.4        |
# | time/                   |              |
# |    fps                  | 21679        |
# |    iterations           | 3            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 600000       |
# | train/                  |              |
# |    approx_kl            | 0.0005802816 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0147      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.3         |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -7.97e-05    |
# |    std                  | 1            |
# |    value_loss           | 60.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -33.8        |
# | time/                   |              |
# |    fps                  | 20036        |
# |    iterations           | 4            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 800000       |
# | train/                  |              |
# |    approx_kl            | 0.0016563816 |
# |    clip_fraction        | 0.00741      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.00132     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.1         |
# |    n_updates            | 9            |
# |    policy_gradient_loss | -0.000338    |
# |    std                  | 1            |
# |    value_loss           | 62.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -34.8        |
# | time/                   |              |
# |    fps                  | 19314        |
# |    iterations           | 5            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 1000000      |
# | train/                  |              |
# |    approx_kl            | 0.0018822439 |
# |    clip_fraction        | 0.00573      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0443       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.9         |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.000319    |
# |    std                  | 1            |
# |    value_loss           | 38.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -27.9        |
# | time/                   |              |
# |    fps                  | 18675        |
# |    iterations           | 6            |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 1200000      |
# | train/                  |              |
# |    approx_kl            | 0.0019933134 |
# |    clip_fraction        | 0.00477      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.1         |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.000144    |
# |    std                  | 1.01         |
# |    value_loss           | 45.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -41.7        |
# | time/                   |              |
# |    fps                  | 18277        |
# |    iterations           | 7            |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 1400000      |
# | train/                  |              |
# |    approx_kl            | 0.0008795594 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.000145    |
# |    std                  | 1.01         |
# |    value_loss           | 34.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -22.1        |
# | time/                   |              |
# |    fps                  | 18076        |
# |    iterations           | 8            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 1600000      |
# | train/                  |              |
# |    approx_kl            | 0.0017652421 |
# |    clip_fraction        | 0.00504      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.307        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.9         |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.00029     |
# |    std                  | 1.01         |
# |    value_loss           | 34.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -25.1        |
# | time/                   |              |
# |    fps                  | 17847        |
# |    iterations           | 9            |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 1800000      |
# | train/                  |              |
# |    approx_kl            | 0.0015753437 |
# |    clip_fraction        | 0.00705      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.000214    |
# |    std                  | 1.01         |
# |    value_loss           | 29.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -28.3        |
# | time/                   |              |
# |    fps                  | 17604        |
# |    iterations           | 10           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0029888034 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.91         |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.000857    |
# |    std                  | 1.01         |
# |    value_loss           | 22.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -18          |
# | time/                   |              |
# |    fps                  | 17597        |
# |    iterations           | 11           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 2200000      |
# | train/                  |              |
# |    approx_kl            | 0.0026665865 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.74         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000737    |
# |    std                  | 1.01         |
# |    value_loss           | 22.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -13.8        |
# | time/                   |              |
# |    fps                  | 17475        |
# |    iterations           | 12           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 2400000      |
# | train/                  |              |
# |    approx_kl            | 0.0026421878 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 33           |
# |    policy_gradient_loss | -0.00079     |
# |    std                  | 1            |
# |    value_loss           | 25.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -9.51        |
# | time/                   |              |
# |    fps                  | 17510        |
# |    iterations           | 13           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 2600000      |
# | train/                  |              |
# |    approx_kl            | 0.0026024543 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.7          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00074     |
# |    std                  | 0.997        |
# |    value_loss           | 18.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -7.89        |
# | time/                   |              |
# |    fps                  | 17575        |
# |    iterations           | 14           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 2800000      |
# | train/                  |              |
# |    approx_kl            | 0.0037183713 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.85         |
# |    n_updates            | 39           |
# |    policy_gradient_loss | -0.00047     |
# |    std                  | 0.992        |
# |    value_loss           | 12.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -17.9       |
# | time/                   |             |
# |    fps                  | 17566       |
# |    iterations           | 15          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 3000000     |
# | train/                  |             |
# |    approx_kl            | 0.003979557 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.15        |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.00114    |
# |    std                  | 0.986       |
# |    value_loss           | 17.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -8.61        |
# | time/                   |              |
# |    fps                  | 17540        |
# |    iterations           | 16           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 3200000      |
# | train/                  |              |
# |    approx_kl            | 0.0036809996 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.59         |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.981        |
# |    value_loss           | 15.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.379       |
# | time/                   |              |
# |    fps                  | 17432        |
# |    iterations           | 17           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 3400000      |
# | train/                  |              |
# |    approx_kl            | 0.0048773168 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.6          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.976        |
# |    value_loss           | 12.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -2.59        |
# | time/                   |              |
# |    fps                  | 17445        |
# |    iterations           | 18           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 3600000      |
# | train/                  |              |
# |    approx_kl            | 0.0051693292 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.51         |
# |    n_updates            | 51           |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.969        |
# |    value_loss           | 11.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 2.47         |
# | time/                   |              |
# |    fps                  | 17451        |
# |    iterations           | 19           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 3800000      |
# | train/                  |              |
# |    approx_kl            | 0.0058989776 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.83         |
# |    n_updates            | 54           |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.962        |
# |    value_loss           | 7.76         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.0842      |
# | time/                   |              |
# |    fps                  | 17475        |
# |    iterations           | 20           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0058668866 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.98         |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.000822    |
# |    std                  | 0.953        |
# |    value_loss           | 6.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 2.79         |
# | time/                   |              |
# |    fps                  | 17392        |
# |    iterations           | 21           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 4200000      |
# | train/                  |              |
# |    approx_kl            | 0.0054523796 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00121     |
# |    std                  | 0.946        |
# |    value_loss           | 5.65         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.83       |
# | time/                   |             |
# |    fps                  | 17326       |
# |    iterations           | 22          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 4400000     |
# | train/                  |             |
# |    approx_kl            | 0.005466965 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34        |
# |    n_updates            | 63          |
# |    policy_gradient_loss | -0.000511   |
# |    std                  | 0.937       |
# |    value_loss           | 4.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 2.83        |
# | time/                   |             |
# |    fps                  | 17281       |
# |    iterations           | 23          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 4600000     |
# | train/                  |             |
# |    approx_kl            | 0.004228508 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21        |
# |    n_updates            | 66          |
# |    policy_gradient_loss | -0.00158    |
# |    std                  | 0.927       |
# |    value_loss           | 4.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 4.88         |
# | time/                   |              |
# |    fps                  | 17261        |
# |    iterations           | 24           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 4800000      |
# | train/                  |              |
# |    approx_kl            | 0.0042899703 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96         |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -0.00154     |
# |    std                  | 0.918        |
# |    value_loss           | 3.85         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 7.42         |
# | time/                   |              |
# |    fps                  | 17257        |
# |    iterations           | 25           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0038263346 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00129     |
# |    std                  | 0.907        |
# |    value_loss           | 3.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 8.13        |
# | time/                   |             |
# |    fps                  | 17237       |
# |    iterations           | 26          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 5200000     |
# | train/                  |             |
# |    approx_kl            | 0.006179248 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.000609   |
# |    std                  | 0.894       |
# |    value_loss           | 2.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 8.08        |
# | time/                   |             |
# |    fps                  | 17206       |
# |    iterations           | 27          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 5400000     |
# | train/                  |             |
# |    approx_kl            | 0.004074418 |
# |    clip_fraction        | 0.0291      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 78          |
# |    policy_gradient_loss | -0.000367   |
# |    std                  | 0.884       |
# |    value_loss           | 2.5         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 9.54         |
# | time/                   |              |
# |    fps                  | 17175        |
# |    iterations           | 28           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 5600000      |
# | train/                  |              |
# |    approx_kl            | 0.0032439828 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4          |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.000614    |
# |    std                  | 0.876        |
# |    value_loss           | 2.96         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 9.39         |
# | time/                   |              |
# |    fps                  | 17126        |
# |    iterations           | 29           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 5800000      |
# | train/                  |              |
# |    approx_kl            | 0.0020761406 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00115     |
# |    std                  | 0.868        |
# |    value_loss           | 2.31         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 9.62         |
# | time/                   |              |
# |    fps                  | 17157        |
# |    iterations           | 30           |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 6000000      |
# | train/                  |              |
# |    approx_kl            | 0.0032812052 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.666        |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.856        |
# |    value_loss           | 1.41         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 10.5        |
# | time/                   |             |
# |    fps                  | 17201       |
# |    iterations           | 31          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 6200000     |
# | train/                  |             |
# |    approx_kl            | 0.004778924 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.691       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00138    |
# |    std                  | 0.842       |
# |    value_loss           | 1.41        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 17235        |
# |    iterations           | 32           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 6400000      |
# | train/                  |              |
# |    approx_kl            | 0.0011517813 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.593        |
# |    n_updates            | 93           |
# |    policy_gradient_loss | -0.000367    |
# |    std                  | 0.831        |
# |    value_loss           | 1.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 11.6         |
# | time/                   |              |
# |    fps                  | 17198        |
# |    iterations           | 33           |
# |    time_elapsed         | 383          |
# |    total_timesteps      | 6600000      |
# | train/                  |              |
# |    approx_kl            | 0.0034446411 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.633        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.595        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000828    |
# |    std                  | 0.822        |
# |    value_loss           | 1.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 11.6         |
# | time/                   |              |
# |    fps                  | 17152        |
# |    iterations           | 34           |
# |    time_elapsed         | 396          |
# |    total_timesteps      | 6800000      |
# | train/                  |              |
# |    approx_kl            | 0.0023180558 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.633        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.583        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -0.00056     |
# |    std                  | 0.813        |
# |    value_loss           | 1.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 17150        |
# |    iterations           | 35           |
# |    time_elapsed         | 408          |
# |    total_timesteps      | 7000000      |
# | train/                  |              |
# |    approx_kl            | 0.0022961057 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.582        |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -0.000609    |
# |    std                  | 0.801        |
# |    value_loss           | 1.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 17131        |
# |    iterations           | 36           |
# |    time_elapsed         | 420          |
# |    total_timesteps      | 7200000      |
# | train/                  |              |
# |    approx_kl            | 0.0031905212 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.611        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.000548    |
# |    std                  | 0.791        |
# |    value_loss           | 1.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 17094       |
# |    iterations           | 37          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 7400000     |
# | train/                  |             |
# |    approx_kl            | 0.003700404 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.574       |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.000586   |
# |    std                  | 0.783       |
# |    value_loss           | 1.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 17057        |
# |    iterations           | 38           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 7600000      |
# | train/                  |              |
# |    approx_kl            | 0.0024941901 |
# |    clip_fraction        | 0.00812      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.62         |
# |    n_updates            | 111          |
# |    policy_gradient_loss | -0.000359    |
# |    std                  | 0.778        |
# |    value_loss           | 1.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 17009        |
# |    iterations           | 39           |
# |    time_elapsed         | 458          |
# |    total_timesteps      | 7800000      |
# | train/                  |              |
# |    approx_kl            | 0.0029524195 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.629        |
# |    n_updates            | 114          |
# |    policy_gradient_loss | -0.000162    |
# |    std                  | 0.77         |
# |    value_loss           | 1.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 17019        |
# |    iterations           | 40           |
# |    time_elapsed         | 470          |
# |    total_timesteps      | 8000000      |
# | train/                  |              |
# |    approx_kl            | 0.0029578998 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.59         |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -0.000436    |
# |    std                  | 0.761        |
# |    value_loss           | 1.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 17006        |
# |    iterations           | 41           |
# |    time_elapsed         | 482          |
# |    total_timesteps      | 8200000      |
# | train/                  |              |
# |    approx_kl            | 0.0023756544 |
# |    clip_fraction        | 0.00378      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.665        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.634        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000179    |
# |    std                  | 0.755        |
# |    value_loss           | 1.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 16965        |
# |    iterations           | 42           |
# |    time_elapsed         | 495          |
# |    total_timesteps      | 8400000      |
# | train/                  |              |
# |    approx_kl            | 0.0016308678 |
# |    clip_fraction        | 0.00491      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.662        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.621        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | 0.000123     |
# |    std                  | 0.749        |
# |    value_loss           | 1.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 11.8         |
# | time/                   |              |
# |    fps                  | 16902        |
# |    iterations           | 43           |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 8600000      |
# | train/                  |              |
# |    approx_kl            | 0.0013224937 |
# |    clip_fraction        | 0.00658      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.667        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.613        |
# |    n_updates            | 126          |
# |    policy_gradient_loss | -0.000166    |
# |    std                  | 0.74         |
# |    value_loss           | 1.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 16868        |
# |    iterations           | 44           |
# |    time_elapsed         | 521          |
# |    total_timesteps      | 8800000      |
# | train/                  |              |
# |    approx_kl            | 0.0025403858 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.633        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -0.000227    |
# |    std                  | 0.734        |
# |    value_loss           | 1.27         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 16851       |
# |    iterations           | 45          |
# |    time_elapsed         | 534         |
# |    total_timesteps      | 9000000     |
# | train/                  |             |
# |    approx_kl            | 0.000868918 |
# |    clip_fraction        | 0.00337     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.639       |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -4.53e-05   |
# |    std                  | 0.729       |
# |    value_loss           | 1.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 12.9         |
# | time/                   |              |
# |    fps                  | 16829        |
# |    iterations           | 46           |
# |    time_elapsed         | 546          |
# |    total_timesteps      | 9200000      |
# | train/                  |              |
# |    approx_kl            | 0.0022801443 |
# |    clip_fraction        | 0.0066       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.2         |
# |    explained_variance   | 0.683        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.629        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -0.000348    |
# |    std                  | 0.723        |
# |    value_loss           | 1.26         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | 13.5          |
# | time/                   |               |
# |    fps                  | 16836         |
# |    iterations           | 47            |
# |    time_elapsed         | 558           |
# |    total_timesteps      | 9400000       |
# | train/                  |               |
# |    approx_kl            | 0.00086660654 |
# |    clip_fraction        | 0.00329       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.18         |
# |    explained_variance   | 0.687         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.625         |
# |    n_updates            | 138           |
# |    policy_gradient_loss | -0.00011      |
# |    std                  | 0.717         |
# |    value_loss           | 1.26          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 16844        |
# |    iterations           | 48           |
# |    time_elapsed         | 569          |
# |    total_timesteps      | 9600000      |
# | train/                  |              |
# |    approx_kl            | 0.0016994316 |
# |    clip_fraction        | 0.00427      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.629        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -0.000321    |
# |    std                  | 0.71         |
# |    value_loss           | 1.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 16803       |
# |    iterations           | 49          |
# |    time_elapsed         | 583         |
# |    total_timesteps      | 9800000     |
# | train/                  |             |
# |    approx_kl            | 0.001799823 |
# |    clip_fraction        | 0.00247     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.615       |
# |    n_updates            | 144         |
# |    policy_gradient_loss | 9.68e-05    |
# |    std                  | 0.706       |
# |    value_loss           | 1.27        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 16791        |
# |    iterations           | 50           |
# |    time_elapsed         | 595          |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0024174105 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.685        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.641        |
# |    n_updates            | 147          |
# |    policy_gradient_loss | -0.000128    |
# |    std                  | 0.7          |
# |    value_loss           | 1.32         |
# ------------------------------------------

# %%
from mbt_gym.agents.SbAgent import SbAgent

ppo_agent = SbAgent(model)

results, fig, total_rewards = generate_results_table_and_hist(vec_env= sb_env ,agent= ppo_agent)

print(results) 

fig
# Out:
# d:\Anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.num_trajectories to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_trajectories` for environment variables or `env.get_wrapper_attr('num_trajectories')` that will search the reminding wrappers.
#   logger.warn(
# d:\Anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.n_steps to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.n_steps` for environment variables or `env.get_wrapper_attr('n_steps')` that will search the reminding wrappers.
#   logger.warn(
# d:\Desktop\Files\Master\Courses\MA4\Reinforcement Learning\Project\Reinforcement-Learning\mbt_gym\gym\helpers\plotting.py:104: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   results.loc[:, "Mean spread"] = 2 * np.mean(half_spreads)
#            Mean spread   Mean PnL   Std PnL Mean terminal inventory  \
# Inventory     2.819023  16.439588  6.708126                     0.0
#
#           Std terminal inventory
# Inventory                    0.0

# %%
print(total_rewards.mean())
# Out:
# 16.32530065592538

# %% [markdown]
# 1000 trajectories with 100 steps
#
# We will plot the mean rewards of the 1000 trajectories as a function of the number of steps.

# %%
observations, actions, rewards = generate_trajectory(sb_env, ppo_agent)

rew_1 = rewards[5].reshape(-1)

rew_average = rewards.mean(axis=0).reshape(-1)

plt.plot(rew_1)

plt.plot(rew_average, color = 'red')
plt.ylabel("Reward")
plt.xlabel("Steps")
plt.title("Reward per step for a single trajectory and average reward over 1000 trajectories")
plt.show()

print("Average reward cumulated over 200 steps: ", rew_average.sum())
# Out:
# d:\Anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.num_trajectories to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_trajectories` for environment variables or `env.get_wrapper_attr('num_trajectories')` that will search the reminding wrappers.
#   logger.warn(
# d:\Anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.n_steps to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.n_steps` for environment variables or `env.get_wrapper_attr('n_steps')` that will search the reminding wrappers.
#   logger.warn(
# Average reward cumulated over 200 steps:  16.212043519313678

# %%
print(actions.shape)
# Out:
# (1000, 2, 200)

# %%
print(observations.shape)
# Out:
# (1000, 2, 201)

# %% [markdown]
# I could incorporate the Sharpe Ratio with the following formula,
#
# $$
# R_{t+1} = \frac{P_{t+1} - P_t + D_{t+1}}{P_t}
# $$
#
# Account the produce of buying and selling the assest as the dividend yield

# %% [markdown]
# **INCORPORATE**
#
# - Sharpe Ratio
# - Is the investor constrainted, can he short sell? If no, it will be interesting to see the effect of the constraint depending on the volatility of the environment

# %%
observations, actions, rewards = generate_trajectory(sb_env, ppo_agent, seed = 1)

rewards = np.squeeze(rewards, axis=1)
# Out:
# (2,)
# c:\Users\jean-\OneDrive\Bureau\MA2\Reinforcement Learning\Reinforcement-Learning\.venv3108\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.seed to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.seed` for environment variables or `env.get_wrapper_attr('seed')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# Plot the midprice bid half spread and midprice ask half spread

# %%
plt.plot(actions[200,1,:], label = "Ask")
plt.plot(actions[200,0,:], label= "Bid")

plt.legend()
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
cum_rewards = np.cumsum(rewards, axis=-1)


plt.plot(cum_rewards[200])
plt.show()

plt.hist(cum_rewards[:,-1], bins = 50, density = True, alpha = 0.6, color = 'b')
plt.title("Histogram of cumulative rewards at the end of the episode")
plt.show()

# %% [markdown]
# That is the cash index of the market maker, I dont know why but it always finish with 0

# %%
plt.plot(observations[200,0,:])

# %% [markdown]
# There is an issue, according to the following result we always finish with no inventory and it increase linearly for all trajectories.
#
# I think there is an issue with the code, the following plot cannot be the inventory index but the time index.

# %%
print(observations[:, INVENTORY_INDEX, :].shape)

plt.plot(observations[200, INVENTORY_INDEX, :])
# Out:
# (1000, 201)

# %%
x, _, _ = generate_trajectory(sb_env, ppo_agent, seed = 1)
# Out:
# (2,)

# %%
obs, rewards, dones, infos = sb_env.step_wait()

print(obs.shape)
print(rewards.shape)
print(dones.shape)
print(len(infos))


extracted_infos = [item["terminal_observation"] for item in infos]

df = pd.DataFrame(extracted_infos,columns = ["Cash", "Inventory"])

plt.hist(df["Cash"], bins = 20, density = True, alpha = 0.6, color = 'b')

df.head()
# Out:
# (1000, 2)
# (1000,)
# (1000,)
# 1000
#    Cash  Inventory
# 0   0.0        1.0
# 1   2.0        1.0
# 2   0.0        1.0
# 3   1.0        1.0
# 4   2.0        1.0

# %%
plt.hist(obs[:,0])
plt.show()

obs[:,1]
# Out:
# array([0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145, 0.145,
#        0.145])

# %%
plt.hist(rewards, bins = 20, density = True, alpha = 0.6, color = 'b')
# Out:
# (array([0.00598591, 0.        , 0.00598591, 0.        , 0.00598591,
#         0.02992955, 0.16760548, 5.31548808, 0.05387319, 0.        ,
#         0.06584501, 0.03591546, 0.00598591, 0.10774638, 0.00598591,
#         0.01197182, 0.04190137, 0.00598591, 0.07183092, 0.04788728]),
#  array([-1.26105692, -1.09399795, -0.92693897, -0.75987999, -0.59282102,
#         -0.42576204, -0.25870306, -0.09164409,  0.07541489,  0.24247387,
#          0.40953284,  0.57659182,  0.7436508 ,  0.91070977,  1.07776875,
#          1.24482773,  1.4118867 ,  1.57894568,  1.74600466,  1.91306363,
#          2.08012261]),
#  <BarContainer object of 20 artists>)
